# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from descriptive_tables import *
import missingno as msno
import seaborn as sns

# %%
df=pd.read_pickle(r"C:\Users\orlyk\readmissions\project\preprocessed\microbiology\microbiology_for_model\microbiology_preprocessed.pkl")
df_pop=pd.read_pickle(r"C:\Users\orlyk\readmissions\project\preprocessed\population\population_for_model\df_basic_data_short.pkl")

# %%
l_casenum=df_pop[["CaseNum","year"]]
df=df.reset_index(drop=True)
df=pd.merge(l_casenum,df,on="CaseNum",how="left")

df=df.sort_values(by='year', ascending=False)
df.shape
# Out:
# (396824, 10)

# %%
df=df.sort_values(by='year', ascending=False)

a=msno.matrix(df)

# %%
df_grouped=df.groupby(by="year")
df_grouped.count()
# Out:
#       CaseNum  num_of_pos_cult  positive_flag  num_of_organisms  \
# year
# 2011    46128             6064           6064              6064
# 2012    47659             6506           6506              6506
# 2013    46630             6293           6293              6293
# 2014    45900             6559           6559              6559
# 2015    47444             6897           6897              6897
# 2016    46592             6466           6466              6466
# 2017    46573             6130           6130              6130
# 2018    46074             6274           6274              6274
# 2019    23824             3043           3043              3043
#
#       category_anaerobe  category_candida  category_negative  \
# year
# 2011               6064              6064               6064
# 2012               6506              6506               6506
# 2013               6293              6293               6293
# 2014               6559              6559               6559
# 2015               6897              6897               6897
# 2016               6466              6466               6466
# 2017               6130              6130               6130
# 2018               6274              6274               6274
# 2019               3043              3043               3043
#
#       category_positive  contaminant
# year
# 2011               6064         6064
# 2012               6506         6506
# 2013               6293         6293
# 2014               6559         6559
# 2015               6897         6897
# 2016               6466         6466
# 2017               6130         6130
# 2018               6274         6274
# 2019               3043         3043

# %%
msno.bar(df)
