# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from descriptive_tables import *
import missingno as msno

# %%
output_path="C:/Users/orlyk/readmissions/project/descriptives/labs/blood_count/"
output_figures="C:/Users/orlyk/readmissions/project/descriptives/labs/blood_count/figures/"

# %%
df=pd.read_pickle(r"C:\Users\orlyk\readmissions\project\preprocessed\labs\blood_count\lab_count_for_model\blood_count_preprocessed.pkl")
df_pop=pd.read_pickle(r"C:\Users\orlyk\readmissions\project\preprocessed\population\population_for_model\df_basic_data_short.pkl")

# %%
l_casenum=df_pop[["CaseNum","year"]]

df=pd.merge(l_casenum,df,on="CaseNum",how="left")

df=df.sort_values(by='year', ascending=False)
df.shape
# Out:
# (396824, 146)

# %%
df_last=df.filter(regex='result_last')

msno.matrix(df_last)
# Out:
# (396824, 18)

# %%
msno.bar(df_last)

# %%
df_last_all=df.filter(regex='last')
df_last_all["date_time_basophils_abs_last"]=pd.to_datetime(df_last_all["date_time_basophils_abs_last"])
df_last_all['year'] = df['date_time_basophils_abs_last'].dt.year

df_year=df_last_all.groupby('year').count()
df_year=df_year["hgb_result_last"]
print(df_year)
# Out:
# year
# 2011.0    38419
# 2012.0    39232
# 2013.0    38261
# 2014.0    37651
# 2015.0    38489
# 2016.0    38274
# 2017.0    38255
# 2018.0    37242
# 2019.0    18374
# 2020.0       11
# Name: hgb_result_last, dtype: int64
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
