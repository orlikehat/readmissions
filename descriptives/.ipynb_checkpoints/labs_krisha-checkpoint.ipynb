# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from descriptive_tables import *
import missingno as msno
import seaborn as sns

# %%
output_path="C:/Users/orlyk/readmissions/project/descriptives/labs/blood_chem/"
output_figures="C:/Users/orlyk/readmissions/project/descriptives/labs/blood_chem/figures/"

# %%
df=pd.read_pickle(r"C:\Users\orlyk\readmissions\project\preprocessed\labs\blood_chem\lab_blood_chem_for_model\blood_chem_results_only.pkl")
df_pop=pd.read_pickle(r"C:\Users\orlyk\readmissions\project\preprocessed\population\population_for_model\df_basic_data_short.pkl")

# %%
l_casenum=df_pop[["CaseNum","year"]]

df=pd.merge(l_casenum,df,on="CaseNum",how="left")

df=df.sort_values(by='year', ascending=False)
df.shape
# Out:
# (396824, 138)

# %%
df_last=df.filter(regex='result_last')

a=msno.matrix(df_last)

# %%
msno.bar(df_last)

# %%
df_last=pd.concat([df_last, l_casenum], axis=1)
df_last.head()
# Out:
#    albumin_result_last  alkaline_phos_result_last  amylase_result_last  \
# 0                 42.0                        NaN                  NaN
# 1                 33.0                       68.0                 72.0
# 2                 39.0                       77.0                  NaN
# 3                 41.0                       38.0                  NaN
# 4                 38.0                       31.0                  NaN
#
#    AST_result_last  bilirubin_result_last  BNP_result_last  BUN_result_last  \
# 0              NaN                    NaN              NaN             13.0
# 1             13.0                   0.08              NaN             17.0
# 2             41.0                   0.38              NaN             22.0
# 3             28.0                   0.50              NaN             17.0
# 4              NaN                   0.60              NaN             14.0
#
#    chloride_result_last  CPK_result_last  creatinine_result_last  ...  \
# ...

# %%
#df_last_all["date_time_basophils_abs_last"]=pd.to_datetime(df_last_all["date_time_basophils_abs_last"])
#df_last_all['year'] = df['date_time_basophils_abs_last'].dt.year

df_year=df_last.groupby('year').count()
df_year.head(11)
#df_year=df_year["hgb_result_last"]
#print(df_year)
# Out:
#       albumin_result_last  alkaline_phos_result_last  amylase_result_last  \
# year
# 2011                28022                      27173                 6684
# 2012                27084                      26327                 7862
# 2013                26538                      26024                12572
# 2014                26611                      26027                13711
# 2015                28155                      27370                16732
# 2016                27909                      26920                16437
# 2017                27365                      26641                16880
# 2018                26565                      26113                11635
# 2019                13193                      12833                 4207
#
#       AST_result_last  bilirubin_result_last  BNP_result_last  \
# year
# 2011            21453                  28665                0
# 2012            18301                  28083                0
# ...

# %%
df_last_short = df_last.dropna(thresh=0.55*len(df_last), axis=1)

# %%
corr = df_last_short.corr()
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
